# %% [markdown]
# <a href="https://colab.research.google.com/github/CybergoreDali/wavenet-music-generation/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ibab/tensorflow-wavenet.git
# Out:
# Cloning into 'tensorflow-wavenet'...
# remote: Enumerating objects: 918, done.
# remote: Total 918 (delta 0), reused 0 (delta 0), pack-reused 918
# Receiving objects: 100% (918/918), 344.09 KiB | 641.00 KiB/s, done.
# Resolving deltas: 100% (525/525), done.

# %%
pip install -r tensorflow-wavenet/requirements_gpu.txt
# Out:
# ...
#      |████████████████████████████████| 320.4MB 54kB/s
# ...

# %%
ls
# Out:
# sample_data/  tensorflow-wavenet/

# %%
# !wget https://cloud.puhoy.net/s/m9LrTxpMAon62MR/download
# Out:
# --2020-08-27 10:55:23--  https://cloud.puhoy.net/s/m9LrTxpMAon62MR/download
# Resolving cloud.puhoy.net (cloud.puhoy.net)... 49.12.70.197
# Connecting to cloud.puhoy.net (cloud.puhoy.net)|49.12.70.197|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 848655031 (809M) [application/zip]
# Saving to: ‘download’
#
# download            100%[===================>] 809.34M  2.66MB/s    in 4m 54s
#
# 2020-08-27 11:00:20 (2.75 MB/s) - ‘download’ saved [848655031/848655031]

# %%
# !unzip download
# Out:
# Archive:  download
#    creating: mp3/
#   inflating: mp3/01 Skrve Snaemy.mp3
#   inflating: mp3/01 Aura Leta.mp3
#   inflating: mp3/08 - Prem I Um.mp3
#   inflating: mp3/03 M Muh Seeng Wuh.mp3
#   inflating: mp3/01-psykovsky_-_da_budet-mycel.mp3
#   inflating: mp3/01-psykovsky_-_amoidioma-mycel.mp3
#   inflating: mp3/02 Mother Toddler.mp3
#   inflating: mp3/11 - Worlds Of Wisdom.mp3
#   inflating: mp3/13 - RS Lightmusic.mp3
#   inflating: mp3/02 - Stone Sea.mp3
#   inflating: mp3/06 Lovei Swhat.mp3
#   inflating: mp3/07-psykovsky_-_to_now_knows_when-mycel.mp3
#   inflating: mp3/12 - PC Transmission.mp3
#   inflating: mp3/04 Unanga Raga.mp3
#   inflating: mp3/05 Bar Maleo.mp3
#   inflating: mp3/09 - Now Here Nowhere.mp3
#   inflating: mp3/10 - Holy Black  Little Lark.mp3
#   inflating: mp3/02-psykovsky_-_genito_genito-mycel.mp3
#   inflating: mp3/06-psykovsky_-_games_for_may-mycel.mp3
#   inflating: mp3/02 Burning Bridges.mp3
#   inflating: mp3/07 Tanetsveta.mp3
# ...

# %%
mv mp3/15\ -\ Dadme\ albricios\ hijos\ d\'Eva.mp3 mp3/15Dadme.mp3

# %%
ls wavs
# Out:
# '01 Aura Leta.wav'
# '01 - Ela Na Pame.wav'
#  01-psykovsky_-_amoidioma-mycel.wav
#  01-psykovsky_-_da_budet-mycel.wav
# '01 Skrve Snaemy.wav'
# '02 Burning Bridges.wav'
# '02 Mother Toddler.wav'
#  02-psykovsky_-_genito_genito-mycel.wav
# '02 - Stone Sea.wav'
# '03 M Muh Seeng Wuh.wav'
# '03 Moydo Dyr.wav'
#  03-psykovsky_-_gde_nivy_schshebechut-mycel.wav
# '03 - So We Sailed Till We Found.wav'
# '04 - Doors Of Perception.wav'
#  04-psykovsky_-_badinerie_dreaming-mycel.wav
# '04 Suddenly.wav'
# '04 Unanga Raga.wav'
# '05 Bar Maleo.wav'
#  05-psykovsky_-_wont_forget_you-mycel.wav
# '05 R.U. Happy.wav'
# '05 - Variant On The Right.wav'
# '06 Bezdne Vselennoy.wav'
# '06 - Call Of Beauty.wav'
# '06 Lovei Swhat.wav'
#  06-psykovsky_-_games_for_may-mycel.wav
# '07 Iskry Sveteal.wav'
# '07 - Many Many Krishnas.wav'
#  07-psykovsky_-_to_now_knows_when-mycel.wav
# '07 Tanetsveta.wav'
# '08 - Prem I Um.wav'
# '09 - Now Here Nowhere.wav'
# '10 - Holy Black  Little Lark.wav'
# ...

# %%
# %%bash
# mkdir wavs
# for file in "./mp3/"*.mp3; do
# 	ffmpeg -i "$file" -ar 16000 -ac 1 "./wavs/""`basename "$file" .mp3`.wav"
# done
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !python ./tensorflow-wavenet/train.py --help
# Out:
# 2020-08-27 10:50:54.929179: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# usage: train.py [-h] [--batch_size BATCH_SIZE] [--data_dir DATA_DIR]
#                 [--store_metadata STORE_METADATA] [--logdir LOGDIR]
#                 [--logdir_root LOGDIR_ROOT] [--restore_from RESTORE_FROM]
#                 [--checkpoint_every CHECKPOINT_EVERY] [--num_steps NUM_STEPS]
#                 [--learning_rate LEARNING_RATE]
#                 [--wavenet_params WAVENET_PARAMS] [--sample_size SAMPLE_SIZE]
#                 [--l2_regularization_strength L2_REGULARIZATION_STRENGTH]
#                 [--silence_threshold SILENCE_THRESHOLD]
#                 [--optimizer {adam,sgd,rmsprop}] [--momentum MOMENTUM]
#                 [--histograms HISTOGRAMS] [--gc_channels GC_CHANNELS]
#                 [--max_checkpoints MAX_CHECKPOINTS]
#
# WaveNet example network
#
# optional arguments:
# ...

# %%
cd tensorflow-wavenet/
# Out:
# /content/tensorflow-wavenet

# %%
# !pip install tensorflow==1.0.1
# Out:
# ...
#      |████████████████████████████████| 44.5MB 68kB/s
# ...
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# ...

# %%
# !python train.py --data_dir="../wavs/"
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:455: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:456: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:457: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
